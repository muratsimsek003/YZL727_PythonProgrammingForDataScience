# %% [markdown]
# #PANDAS

# %% [markdown]
# # Pandas Series
# # Veri Okuma (Reading Data)
# # Veriye Hızlı Bakış (Quick Look at Data)
# # Pandas'ta Seçim İşlemleri (Selection in Pandas)
# # Toplulaştırma ve Gruplama (Aggregation & Grouping)
# # Apply ve Lambda
# # Birleştirme (Join) İşlemleri

# %% [markdown]
# # Pandas Series

# %%
import pandas as pd

s = pd.Series([10, 77, 12, 4, 5])
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# RangeIndex(start=0, stop=5, step=1) sıfırdan başlıyor indeks, 5 e kadar 1 er 1er artıyor

# %%
s.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Pandas serisinin içinde bulunan eleman sayısı için .size

# %%
s.size
# Out:
# 5

# %% [markdown]
# boyut bilgisi için .ndim

# %%
s.ndim
# Out:
# 1

# %% [markdown]
# pandas serisindeki değerlere erişmek için .values

# %%
s.values
# Out:
# array([10, 77, 12,  4,  5])

# %%
type(s.values)
# Out:
# numpy.ndarray

# %% [markdown]
# pandas serisinin değerleri sorulduğunda indeks bilgisi göz önünde alınmadığı için numpy array olarak tip bilgisi elde ederiz.

# %%
s.head()
# Out:
# 0    10
# 1    77
# 2    12
# 3     4
# 4     5
# dtype: int64

# %%
s.head(3)
# Out:
# 0    10
# 1    77
# 2    12
# dtype: int64

# %%
s.tail()
# Out:
# 0    10
# 1    77
# 2    12
# 3     4
# 4     5
# dtype: int64

# %%
s.tail(3)
# Out:
# 2    12
# 3     4
# 4     5
# dtype: int64

# %% [markdown]
# # DataFrame Yapısı

# %%
import numpy as np
df = pd.DataFrame(data = np.random.randint(0,10,(5,5)), index = ['A','B','C','D','E'],columns = ['Columns1','Columns2','Columns3','Columns4','Columns5'])

# %%
df.head()
# Out:
#    Columns1  Columns2  Columns3  Columns4  Columns5
# A         3         3         9         6         3
# B         5         1         0         1         8
# C         8         9         5         9         2
# D         5         0         9         5         2
# E         8         3         3         2         4

# %%
#############################################
# Veri Okuma (Reading Data)
#############################################
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/yzl727/dataset.csv")
df.head()
# Out:
#    Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0           0    15634602  Hargrave          619    France  Female   42
# 1           1    15647311      Hill          608     Spain  Female   41
# 2           2    15619304      Onio          502    France  Female   42
# 3           3    15701354      Boni          699    France  Female   39
# 4           4    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#############################################
# Veriye Hızlı Bakış (Quick Look at Data)
#############################################
df.tail()
# Out:
#       Unnamed: 0  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995        9995    15606229   Obijiaku          771    France    Male   39
# 9996        9996    15569892  Johnstone          516    France    Male   35
# 9997        9997    15584532        Liu          709    France  Female   36
# 9998        9998    15682355  Sabbatini          772   Germany    Male   42
# 9999        9999    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.describe().T
# Out:
#                    count          mean           std          min  \
# Unnamed: 0       10000.0  4.999500e+03   2886.895680         0.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# Unnamed: 0           2499.75  4.999500e+03  7.499250e+03      9999.00
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# dataframe içerisinde herhangi bir value de null durumu var mı ? .values.any()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df["Age"].head()
# Out:
# 0    42
# 1    41
# 2    42
# 3    39
# 4    43
# Name: Age, dtype: int64

# %%
df["Exited"].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
#############################################
# Pandas'ta Seçim İşlemleri (Selection in Pandas)
#############################################
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df[0:13]
# Out:
#     Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0            0    15634602  Hargrave          619    France  Female   42
# 1            1    15647311      Hill          608     Spain  Female   41
# 2            2    15619304      Onio          502    France  Female   42
# 3            3    15701354      Boni          699    France  Female   39
# 4            4    15737888  Mitchell          850     Spain  Female   43
# 5            5    15574012       Chu          645     Spain    Male   44
# 6            6    15592531  Bartlett          822    France    Male   50
# 7            7    15656148    Obinna          376   Germany  Female   29
# 8            8    15792365        He          501    France    Male   44
# 9            9    15592389        H?          684    France    Male   27
# 10          10    15767821    Bearce          528    France    Male   31
# 11          11    15737173   Andrews          497     Spain    Male   24
# ...

# %%
df.drop(0, axis=0).head()
# Out:
#    Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 1           1    15647311      Hill          608     Spain  Female   41
# 2           2    15619304      Onio          502    France  Female   42
# 3           3    15701354      Boni          699    France  Female   39
# 4           4    15737888  Mitchell          850     Spain  Female   43
# 5           5    15574012       Chu          645     Spain    Male   44
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
#
#    EstimatedSalary  Exited
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# ...

# %%
delete_indexes = [1, 3, 5, 7]
df.drop(delete_indexes, axis=0).head(10)
# Out:
#     Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0            0    15634602  Hargrave          619    France  Female   42
# 2            2    15619304      Onio          502    France  Female   42
# 4            4    15737888  Mitchell          850     Spain  Female   43
# 6            6    15592531  Bartlett          822    France    Male   50
# 8            8    15792365        He          501    France    Male   44
# 9            9    15592389        H?          684    France    Male   27
# 10          10    15767821    Bearce          528    France    Male   31
# 11          11    15737173   Andrews          497     Spain    Male   24
# 12          12    15632264       Kay          476    France  Female   34
# 13          13    15691483      Chin          549    France  Female   25
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0        2       0.00              1          1               1
# ...

# %% [markdown]
# #######################
# # Değişkeni Indexe Çevirmek
# #######################

# %%
df["Age"].head()
# Out:
# 0    42
# 1    41
# 2    42
# 3    39
# 4    43
# Name: Age, dtype: int64

# %%
df.Age.head()
# Out:
# 0    42
# 1    41
# 2    42
# 3    39
# 4    43
# Name: Age, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.index = df["Age"]

# %%
df.drop("Age", axis=1).head()
# Out:
#      Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Tenure  \
# Age
# 42            0    15634602  Hargrave          619    France  Female       2
# 41            1    15647311      Hill          608     Spain  Female       1
# 42            2    15619304      Onio          502    France  Female       8
# 39            3    15701354      Boni          699    France  Female       1
# 43            4    15737888  Mitchell          850     Spain  Female       2
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Age
# 42        0.00              1          1               1        101348.88
# 41    83807.86              1          0               1        112542.58
# 42   159660.80              3          1               0        113931.57
# 39        0.00              2          0               0         93826.63
# 43   125510.82              1          1               1         79084.10
#
#      Exited
# Age
# 42        1
# 41        0
# ...

# %%
df.drop("Unnamed: 0", axis=1).head()
# Out:
#      CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# Age
# 42     15634602  Hargrave          619    France  Female   42       2
# 41     15647311      Hill          608     Spain  Female   41       1
# 42     15619304      Onio          502    France  Female   42       8
# 39     15701354      Boni          699    France  Female   39       1
# 43     15737888  Mitchell          850     Spain  Female   43       2
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Age
# 42        0.00              1          1               1        101348.88
# 41    83807.86              1          0               1        112542.58
# 42   159660.80              3          1               0        113931.57
# 39        0.00              2          0               0         93826.63
# 43   125510.82              1          1               1         79084.10
#
#      Exited
# Age
# 42        1
# 41        0
# 42        1
# 39        0
# 43        0

# %%
df.drop(["Surname","CreditScore"], axis=1)
# Out:
#      Unnamed: 0  CustomerId Geography  Gender  Age  Tenure    Balance  \
# Age
# 42            0    15634602    France  Female   42       2       0.00
# 41            1    15647311     Spain  Female   41       1   83807.86
# 42            2    15619304    France  Female   42       8  159660.80
# 39            3    15701354    France  Female   39       1       0.00
# 43            4    15737888     Spain  Female   43       2  125510.82
# ..          ...         ...       ...     ...  ...     ...        ...
# 39         9995    15606229    France    Male   39       5       0.00
# 35         9996    15569892    France    Male   35      10   57369.61
# 36         9997    15584532    France  Female   36       7       0.00
# 42         9998    15682355   Germany    Male   42       3   75075.31
# 28         9999    15628319    France  Female   28       4  130142.79
#
#      NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Age
# ...

# %% [markdown]
# #######################
# # Indexi Değişkene Çevirmek
# #######################

# %%
df.index
# Out:
# Int64Index([42, 41, 42, 39, 43, 44, 50, 29, 44, 27,
#             ...
#             33, 53, 36, 28, 29, 39, 35, 36, 42, 28],
#            dtype='int64', name='Age', length=10000)

# %%
df["Age"]
# Out:
# Age
# 42    42
# 41    41
# 42    42
# 39    39
# 43    43
#       ..
# 39    39
# 35    35
# 36    36
# 42    42
# 28    28
# Name: Age, Length: 10000, dtype: int64

# %%
df.drop("Age", axis=1, inplace=True)

# %%
df.head()
# Out:
#      Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Tenure  \
# Age
# 42            0    15634602  Hargrave          619    France  Female       2
# 41            1    15647311      Hill          608     Spain  Female       1
# 42            2    15619304      Onio          502    France  Female       8
# 39            3    15701354      Boni          699    France  Female       1
# 43            4    15737888  Mitchell          850     Spain  Female       2
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Age
# 42        0.00              1          1               1        101348.88
# 41    83807.86              1          0               1        112542.58
# 42   159660.80              3          1               0        113931.57
# 39        0.00              2          0               0         93826.63
# 43   125510.82              1          1               1         79084.10
#
#      Exited
# Age
# 42        1
# 41        0
# ...

# %%
data=df.reset_index().head()

# %%
data.head()
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
# 4   43           4    15737888  Mitchell          850     Spain  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# #######################
# # Değişkenler Üzerinde İşlemler
# #######################

# %%
"Age" in data
# Out:
# True

# %%
data.head()
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
# 4   43           4    15737888  Mitchell          850     Spain  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data["Age"].head()
# Out:
# 0    42
# 1    41
# 2    42
# 3    39
# 4    43
# Name: Age, dtype: int64

# %%
data.Age.head()
# Out:
# 0    42
# 1    41
# 2    42
# 3    39
# 4    43
# Name: Age, dtype: int64

# %%
type(data["Age"].head())
# Out:
# pandas.core.series.Series

# %% [markdown]
# data["Age"] şekilde bir seçim yaptığımızda artık bu bir pandas serisidir.

# %%
data[["Age"]].head()
# Out:
#    Age
# 0   42
# 1   41
# 2   42
# 3   39
# 4   43

# %% [markdown]
# data[["Age"]] şekilde iki tane köşeli parantez olarak yazarsak dataframe olarak elde ederiz.

# %%
type(data[["Age"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
data[["Age", "Surname"]]
# Out:
#    Age   Surname
# 0   42  Hargrave
# 1   41      Hill
# 2   42      Onio
# 3   39      Boni
# 4   43  Mitchell

# %%
col_names = ["Age", "Surname", "Geography"]

# %%
data[col_names]
# Out:
#    Age   Surname Geography
# 0   42  Hargrave    France
# 1   41      Hill     Spain
# 2   42      Onio    France
# 3   39      Boni    France
# 4   43  Mitchell     Spain

# %%
data["Age2"] = data["Age"]**2

# %%
data.head()
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
# 4   43           4    15737888  Mitchell          850     Spain  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age2
# 0        101348.88       1  1764
# 1        112542.58       0  1681
# 2        113931.57       1  1764
# ...

# %%
data["Age3"] = data["Age"] / data["Age2"]
data.head()
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
# 4   43           4    15737888  Mitchell          850     Spain  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age2      Age3
# 0        101348.88       1  1764  0.023810
# 1        112542.58       0  1681  0.024390
# ...

# %%
data.drop("Age3", axis=1).head()
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
# 4   43           4    15737888  Mitchell          850     Spain  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age2
# 0        101348.88       1  1764
# 1        112542.58       0  1681
# 2        113931.57       1  1764
# ...

# %%
data.drop(col_names, axis=1).head()
# Out:
#    Unnamed: 0  CustomerId  CreditScore  Gender  Tenure    Balance  \
# 0           0    15634602          619  Female       2       0.00
# 1           1    15647311          608  Female       1   83807.86
# 2           2    15619304          502  Female       8  159660.80
# 3           3    15701354          699  Female       1       0.00
# 4           4    15737888          850  Female       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Age2  \
# 0              1          1               1        101348.88       1  1764
# 1              1          0               1        112542.58       0  1681
# 2              3          1               0        113931.57       1  1764
# 3              2          0               0         93826.63       0  1521
# 4              1          1               1         79084.10       0  1849
#
#        Age3
# 0  0.023810
# 1  0.024390
# 2  0.023810
# 3  0.025641
# 4  0.023256

# %% [markdown]
# #######################
# # iloc & loc
# #######################

# %%
# iloc: integer based selection    indeks bilgisi vererek seçim yapma işlemidir.
data.iloc[0:3]
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited  Age2     Age3
# 0        101348.88       1  1764  0.02381
# 1        112542.58       0  1681  0.02439
# 2        113931.57       1  1764  0.02381

# %%
data.iloc[0, 0]    #0 nci satır e sıfırıncı sütundaki elemanı seç
# Out:
# 42

# %%
# loc: label based selection
data.loc[0:3]      #label based olduğu için 3 dahil oluyor.
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
#
#    EstimatedSalary  Exited  Age2      Age3
# 0        101348.88       1  1764  0.023810
# 1        112542.58       0  1681  0.024390
# 2        113931.57       1  1764  0.023810
# 3         93826.63       0  1521  0.025641

# %%
data.iloc[0:3, 0:3]
# Out:
#    Age  Unnamed: 0  CustomerId
# 0   42           0    15634602
# 1   41           1    15647311
# 2   42           2    15619304

# %%
data.iloc[0:3,"Age"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     872             try:
# --> 873                 self._validate_key(k, i)
#     874             except ValueError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1482         else:
# -> 1483             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1484
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-dbcbcd089313> in <cell line: 1>()
# ...

# %%
data.loc[0:3, "Age"]
# Out:
# 0    42
# 1    41
# 2    42
# 3    39
# Name: Age, dtype: int64

# %%
col_names = ["Age", "Surname", "Geography"]
data.loc[0:3, col_names]
# Out:
#    Age   Surname Geography
# 0   42  Hargrave    France
# 1   41      Hill     Spain
# 2   42      Onio    France
# 3   39      Boni    France

# %% [markdown]
# #######################
# # Koşullu Seçim (Conditional Selection)
# #######################

# %% [markdown]
# Yaşı 20 nin üzerinde olanları seçelim.

# %%
data[data["Age"] > 20].head()
# Out:
#    Age  Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  \
# 0   42           0    15634602  Hargrave          619    France  Female
# 1   41           1    15647311      Hill          608     Spain  Female
# 2   42           2    15619304      Onio          502    France  Female
# 3   39           3    15701354      Boni          699    France  Female
# 4   43           4    15737888  Mitchell          850     Spain  Female
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age2      Age3
# 0        101348.88       1  1764  0.023810
# 1        112542.58       0  1681  0.024390
# ...

# %% [markdown]
# yaşı 20 den büyük olan kaç kişi var

# %%
data[data["Age"] > 20].count()
# Out:
# Age                5
# Unnamed: 0         5
# CustomerId         5
# Surname            5
# CreditScore        5
# Geography          5
# Gender             5
# Tenure             5
# Balance            5
# NumOfProducts      5
# HasCrCard          5
# IsActiveMember     5
# EstimatedSalary    5
# Exited             5
# Age2               5
# Age3               5
# dtype: int64

# %%
data[data["Age"] > 20]["Age"].count()
# Out:
# 5

# %%
data.loc[data["Age"] > 20, ["Age","CreditScore", "Geography"]].head()
# Out:
#    Age  CreditScore Geography
# 0   42          619    France
# 1   41          608     Spain
# 2   42          502    France
# 3   39          699    France
# 4   43          850     Spain

# %%
data.loc[(data["Age"] > 20) & (data["Gender"]=="Female"), ["Gender", "Age","CreditScore", "Geography"]].head()
# Out:
#    Gender  Age  CreditScore Geography
# 0  Female   42          619    France
# 1  Female   41          608     Spain
# 2  Female   42          502    France
# 3  Female   39          699    France
# 4  Female   43          850     Spain

# %%
data["HasCrCard"].value_counts()
# Out:
# 1    3
# 0    2
# Name: HasCrCard, dtype: int64

# %% [markdown]
# #############################################
# # Toplulaştırma ve Gruplama (Aggregation & Grouping)
# #############################################

# %% [markdown]
# # - count()
# # - first()
# # - last()
# # - mean()
# # - median()
# # - min()
# # - max()
# # - std()
# # - var()
# # - sum()
# # - pivot table

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/yzl727/dataset.csv")
df.head()
# Out:
#    Unnamed: 0  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0           0    15634602  Hargrave          619    France  Female   42
# 1           1    15647311      Hill          608     Spain  Female   41
# 2           2    15619304      Onio          502    France  Female   42
# 3           3    15701354      Boni          699    France  Female   39
# 4           4    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df["Age"].mean()
# Out:
# 38.9218

# %%
df["Gender"].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    39.238389
# Male      38.658237
# Name: Age, dtype: float64

# %%
df.groupby("Gender").agg({"Age": "mean"})
# Out:
#               Age
# Gender
# Female  39.238389
# Male    38.658237

# %%
df.groupby("Gender").agg({"Age": ["mean","sum"]})
# Out:
#               Age
#              mean     sum
# Gender
# Female  39.238389  178260
# Male    38.658237  210958

# %%
df.groupby("Gender").agg({"Age": ["mean", "sum"],
                       "EstimatedSalary": "mean"})
# Out:
#               Age         EstimatedSalary
#              mean     sum            mean
# Gender
# Female  39.238389  178260   100601.541382
# Male    38.658237  210958    99664.576931

# %%
df.groupby(["Gender", "Geography"]).agg({"Age": "mean",
                       "EstimatedSalary": "mean"})
# Out:
#                         Age  EstimatedSalary
# Gender Geography
# Female France     38.773994     99564.252755
#        Germany    40.154233    102446.424124
#        Spain      39.199265    100734.107475
# Male   France     38.296404    100174.252495
#        Germany    39.424772     99905.033959
#        Spain      38.649135     98425.687680

# %%
df.groupby(["Gender", "Geography"]).agg({"Age": "mean",
                       "Exited": "count"})
# Out:
#                         Age  Exited
# Gender Geography
# Female France     38.773994    2261
#        Germany    40.154233    1193
#        Spain      39.199265    1089
# Male   France     38.296404    2753
#        Germany    39.424772    1316
#        Spain      38.649135    1388

# %% [markdown]
# #######################
# # Pivot table
# #######################

# %% [markdown]
# pivot table veri içerisindeki kırılımları incelemeye yarar.

# %% [markdown]
# .pivot_table(ilk değişken kırılımlarda ne görmek istediğimizi, satırda ne olsun, sütünda ne olsun)

# %%
df.pivot_table("Age", "Geography", "Exited")
# Out:
# Exited             0          1
# Geography
# France     37.235966  45.133333
# Germany    37.311504  44.894349
# Spain      37.839147  44.147700

# %% [markdown]
# buradaki değerler yaş bilgisinin ortalamalarıdır.

# %%
df.pivot_table("Age", "Geography", "Exited", aggfunc="std")  #aggfuc fonksiyonu kesişimi ne yapmak istediğimizi için kullanılır
# Out:
# Exited             0          1
# Geography
# France     10.113206   9.771531
# Germany    10.066588   9.555490
# Spain      10.190398  10.127583

# %%
df.pivot_table("Age", "Geography", ["Exited", "HasCrCard"])
# Out:
# Exited             0                     1
# HasCrCard          0          1          0          1
# Geography
# France     37.324390  37.199395  45.356846  45.038664
# Germany    37.422037  37.267710  45.658228  44.580589
# Spain      37.871176  37.825364  44.488889  43.982014

# %% [markdown]
# #############################################
# # Apply ve Lambda
# #############################################

# %%
df[["Age", "EstimatedSalary", "CreditScore"]].apply(lambda x: x/10).head()
# Out:
#    Age  EstimatedSalary  CreditScore
# 0  4.2        10134.888         61.9
# 1  4.1        11254.258         60.8
# 2  4.2        11393.157         50.2
# 3  3.9         9382.663         69.9
# 4  4.3         7908.410         85.0

# %% [markdown]
# #############################################
# # Birleştirme (Join) İşlemleri
# #############################################

# %%
import numpy as np
import pandas as pd
m = np.random.randint(1, 30, size=(5, 3))
df1 = pd.DataFrame(m, columns=["var1", "var2", "var3"])

# %%
df1.head()
# Out:
#    var1  var2  var3
# 0     6    29    12
# 1    18     6    24
# 2    25    20    25
# 3    16    17    11
# 4    28    13     2

# %%
df2 = df1 + 99

# %%
df2.head()
# Out:
#    var1  var2  var3
# 0   105   128   111
# 1   117   105   123
# 2   124   119   124
# 3   115   116   110
# 4   127   112   101

# %% [markdown]
# iki dataframe i birleştirmek için .concat() komutu kullanılır

# %%
pd.concat([df1, df2])
# Out:
#    var1  var2  var3
# 0     6    29    12
# 1    18     6    24
# 2    25    20    25
# 3    16    17    11
# 4    28    13     2
# 0   105   128   111
# 1   117   105   123
# 2   124   119   124
# 3   115   116   110
# 4   127   112   101

# %% [markdown]
# burada dümdüz alt alta birleştirdi ve indeksler tekrarladı

# %%
pd.concat([df1, df2], ignore_index=True) #indeks devam eder
# Out:
#    var1  var2  var3
# 0     6    29    12
# 1    18     6    24
# 2    25    20    25
# 3    16    17    11
# 4    28    13     2
# 5   105   128   111
# 6   117   105   123
# 7   124   119   124
# 8   115   116   110
# 9   127   112   101

# %% [markdown]
# #######################
# # Merge ile Birleştirme İşlemleri
# #######################

# %%
df1 = pd.DataFrame({'employees': ['john', 'dennis', 'mark', 'maria'],
                    'group': ['accounting', 'engineering', 'engineering', 'hr']})

# %%
df1.head()
# Out:
#   employees        group
# 0      john   accounting
# 1    dennis  engineering
# 2      mark  engineering
# 3     maria           hr

# %%
df2 = pd.DataFrame({'employees': ['mark', 'john', 'dennis', 'maria'],
                    'start_date': [2010, 2009, 2014, 2019]})

# %%
pd.merge(df1, df2)
# Out:
#   employees        group  start_date
# 0      john   accounting        2009
# 1    dennis  engineering        2014
# 2      mark  engineering        2010
# 3     maria           hr        2019

# %%
pd.merge(df1, df2, on="employees")
# Out:
#   employees        group  start_date
# 0      john   accounting        2009
# 1    dennis  engineering        2014
# 2      mark  engineering        2010
# 3     maria           hr        2019

# %%
df3 = pd.merge(df1, df2)

# %%
df4 = pd.DataFrame({'group': ['accounting', 'engineering', 'hr'],
                    'manager': ['Caner', 'Mustafa', 'Berkcan']})

# %%
df4.head()
# Out:
#          group  manager
# 0   accounting    Caner
# 1  engineering  Mustafa
# 2           hr  Berkcan

# %%
pd.merge(df3, df4)
# Out:
#   employees        group  start_date  manager
# 0      john   accounting        2009    Caner
# 1    dennis  engineering        2014  Mustafa
# 2      mark  engineering        2010  Mustafa
# 3     maria           hr        2019  Berkcan
