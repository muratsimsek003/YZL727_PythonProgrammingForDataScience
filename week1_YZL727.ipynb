# %% [markdown]
# #Veri Bilimi için Python Programlama

# %% [markdown]
# 1.   Değişkenler ve Değişken Yapıları
# 2.   Data Structures (Veri Yapıları)=List, Set, Tuple ,Dictionary
# 3.   Conditions (if -elif-else)
# 4.   Loops (Döngüler)= while, for
# 5.   Functions (Fonksiyonlar)

# %% [markdown]
# ##Değişkenler ve Değişken Yapıları

# %% [markdown]
# integer
#
# float
#
# boolean
#
# string

# %%
x=5

# %%
type(x)
# Out:
# int

# %%
y=3.14
type(y)
# Out:
# float

# %%
var=False
type(var)
# Out:
# bool

# %%
lesson="YZL727"

# %%
type(lesson)
# Out:
# str

# %%
x=5
y=3
z=10

# %%
toplam=x+y

# %%
print(toplam)
# Out:
# 8

# %%
print(z-x)
# Out:
# 5

# %%
print(x*y)
# Out:
# 15

# %%
print(z/x)
# Out:
# 2.0

# %% [markdown]
# Python mod alma (%)

# %%
print(x%y)
# Out:
# 2

# %%
print(x/y)
# Out:
# 1.6666666666666667

# %% [markdown]
# Floor division (//)

# %%
print(x//y)
# Out:
# 1

# %% [markdown]
# python üs alma (**)

# %%
print(x**y)
# Out:
# 125

# %% [markdown]
# String operation

# %%
isim="murat simsek"

# %%
print(isim)
# Out:
# murat simsek

# %%
type(isim)
# Out:
# str

# %%
print(isim.title())
# Out:
# Murat Simsek

# %%
isim
# Out:
# 'murat simsek'

# %%
print(isim.upper())
# Out:
# MURAT SIMSEK

# %%
print(isim.lower())
# Out:
# murat simsek

# %%
x=5
y=2

# %%
x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
x<=y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x=5
y=2

# %%
y<6 and x<10
# Out:
# True

# %%
y<6 or x<10
# Out:
# True

# %%
y<6 or x>10
# Out:
# True

# %%
not(y<6 and x<10)
# Out:
# False

# %% [markdown]
# f-string

# %%
first_name="murat"
last_name="simsek"

# %%
full_name=f"{first_name} {last_name}"
print(full_name)
# Out:
# murat simsek

# %%
full_name=input("Adınızı ve soyadınızı giriniz:")
# Out:
# Adınızı ve soyadınızı giriniz:murat simsek

# %%
print(f"Hello, {full_name.title()}!")
# Out:
# Hello, Murat Simsek!

# %%
print("Languages: \nPython\nJava\nCplusplus")
# Out:
# Languages:
# Python
# Java
# Cplusplus

# %%
language=" python "

# %%
print(language)
# Out:
#  python

# %%
language.rstrip()
# Out:
# ' python'

# %%
language.lstrip()
# Out:
# 'python '

# %%
universe_age=14_000_000_000

# %%
print(universe_age)
# Out:
# 14000000000
